# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/complaints.csv')

# %%
df.head()
# Out:
#    odiNumber                manufacturer  crash   fire  numberOfInjuries  \
# 0   10702705           Kia America, Inc.   True  False                 0
# 1   10713088           Kia America, Inc.  False  False                 0
# 2   10713503    ALUMA TOWER COMPANY, INC  False   True                 0
# 3   10715078           Kia America, Inc.  False  False                 0
# 4   10715844  Volvo Trucks North America  False  False                 0
#
#    numberOfDeaths dateOfIncident dateComplaintFiled          vin  \
# 0               0     03/24/2015         03/30/2015  5XYPG4A36GG
# 1               0     04/24/2015         04/27/2015  5XYPH4A15GG
# 2               0     04/28/2015         04/29/2015  1YGAE1629GB
# 3               0     04/30/2015         05/07/2015          NaN
# 4               0     03/06/2015         05/12/2015  4V4NC9EH7GN
#
#           components                                            summary  \
# ...

# %%
df.shape
# Out:
# (284745, 15)

# %%
df.columns.tolist()
# Out:
# ['odiNumber',
#  'manufacturer',
#  'crash',
#  'fire',
#  'numberOfInjuries',
#  'numberOfDeaths',
#  'dateOfIncident',
#  'dateComplaintFiled',
#  'vin',
#  'components',
#  'summary',
#  'products',
#  'make',
#  'model',
#  'modelYear']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284745 entries, 0 to 284744
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   odiNumber           284745 non-null  int64
#  1   manufacturer        284743 non-null  str
#  2   crash               284745 non-null  bool
#  3   fire                284745 non-null  bool
#  4   numberOfInjuries    284745 non-null  int64
#  5   numberOfDeaths      284745 non-null  int64
#  6   dateOfIncident      284745 non-null  str
#  7   dateComplaintFiled  284745 non-null  str
#  8   vin                 279307 non-null  str
#  9   components          284744 non-null  str
#  10  summary             284732 non-null  str
#  11  products            284745 non-null  str
#  12  make                284745 non-null  str
#  13  model               284745 non-null  str
#  14  modelYear           284745 non-null  int64
# dtypes: bool(2), int64(4), str(9)
# memory usage: 28.8 MB
