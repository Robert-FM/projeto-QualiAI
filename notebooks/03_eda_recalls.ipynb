# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/recalls.csv')

# %%
df.head()
# Out:
#                  Manufacturer NHTSACampaignNumber parkIt parkOutSide  \
# 0      Blue Bird Body Company           14V798000  False       False
# 1      Blue Bird Body Company           14V798000  False       False
# 2           Mack Trucks, Inc.           15V025000  False       False
# 3  Volvo Trucks North America           15V026000  False       False
# 4      Blue Bird Body Company           15V059000  False       False
#
#   ReportReceivedDate                                   Component  \
# 0         17/12/2014                               PARKING BRAKE
# 1         17/12/2014                               PARKING BRAKE
# 2         22/01/2015  PARKING BRAKE:DRIVELINE:HYDRAULIC:ACTUATOR
# 3         22/01/2015  PARKING BRAKE:DRIVELINE:HYDRAULIC:ACTUATOR
# 4         03/02/2015    ENGINE AND ENGINE COOLING:EXHAUST SYSTEM
#
#                                              Summary  \
# 0  Blue Bird Body Company (Blue Bird) is recallin...
# ...

# %%
df.shape
# Out:
# (33309, 15)

# %%
df.columns.to_list()
# Out:
# ['Manufacturer',
#  'NHTSACampaignNumber',
#  'parkIt',
#  'parkOutSide',
#  'ReportReceivedDate',
#  'Component',
#  'Summary',
#  'Consequence',
#  'Remedy',
#  'Notes',
#  'ModelYear',
#  'Make',
#  'Model',
#  'NHTSAActionNumber',
#  'overTheAirUpdate']

# %%
df.shape
# Out:
# (33309, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33309 entries, 0 to 33308
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         33309 non-null  str
#  1   NHTSACampaignNumber  33309 non-null  str
#  2   parkIt               33160 non-null  object
#  3   parkOutSide          33160 non-null  object
#  4   ReportReceivedDate   33309 non-null  str
#  5   Component            33309 non-null  str
#  6   Summary              33309 non-null  str
#  7   Consequence          33309 non-null  str
#  8   Remedy               33309 non-null  str
#  9   Notes                29632 non-null  str
#  10  ModelYear            33309 non-null  int64
#  11  Make                 33309 non-null  str
#  12  Model                33309 non-null  str
#  13  NHTSAActionNumber    803 non-null    str
#  14  overTheAirUpdate     33065 non-null  object
# dtypes: int64(1), object(3), str(11)
# memory usage: 3.8+ MB

# %%
df.isna().sum()
# Out:
# Manufacturer               0
# NHTSACampaignNumber        0
# parkIt                   149
# parkOutSide              149
# ReportReceivedDate         0
# Component                  0
# Summary                    0
# Consequence                0
# Remedy                     0
# Notes                   3677
# ModelYear                  0
# Make                       0
# Model                      0
# NHTSAActionNumber      32506
# overTheAirUpdate         244
# dtype: int64
