# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/car_models.csv')

# %%
df.head()
# Out:
#    modelYear       make       model
# 0       2020        BMW          Z4
# 1       2018  CHEVROLET     BOLT EV
# 2       2022    GENESIS         G90
# 3       2018    FERRARI  488 SPIDER
# 4       2023       AUDI          A4

# %%
df.shape
# Out:
# (6665, 3)

# %%
df.columns.to_list()
# Out:
# ['modelYear', 'make', 'model']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6665 entries, 0 to 6664
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   modelYear  6665 non-null   int64
#  1   make       6665 non-null   str
#  2   model      6665 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 156.3 KB

# %%
df.isna().sum()
# Out:
# modelYear    0
# make         0
# model        0
# dtype: int64

# %%
df["model"].value_counts()
# Out:
# model
# CHALLENGER             18
# FORESTER               18
# CARGO TRAILER          17
# CHEROKEE               16
# JAY FLIGHT             16
#                        ..
# PROLOGUE BEV            1
# ACCORD SEDAN ICE        1
# PILOT ICE               1
# CBR650R                 1
# LAND CRUISER HYBRID     1
# Name: count, Length: 2532, dtype: int64

# %%
df.nunique()
# Out:
# modelYear      12
# make          401
# model        2532
# dtype: int64
