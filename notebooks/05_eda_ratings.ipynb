# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/ratings.csv')

# %%
df.head()
# Out:
#   OverallRating OverallFrontCrashRating FrontCrashDriversideRating  \
# 0             5                       5                          5
# 1     Not Rated               Not Rated                  Not Rated
# 2             5                       4                          4
# 3     Not Rated                       4                          4
# 4             5                       4                          4
#
#   FrontCrashPassengersideRating OverallSideCrashRating  \
# 0                             5                      5
# 1                     Not Rated              Not Rated
# 2                             4                      5
# 3                             4                      5
# 4                             4                      5
#
#   SideCrashDriversideRating SideCrashPassengersideRating  \
# 0                         5                            5
# 1                 Not Rated                    Not Rated
# ...

# %%
df.shape
# Out:
# (2469, 25)

# %%
df.columns.to_list()
# Out:
# ['OverallRating',
#  'OverallFrontCrashRating',
#  'FrontCrashDriversideRating',
#  'FrontCrashPassengersideRating',
#  'OverallSideCrashRating',
#  'SideCrashDriversideRating',
#  'SideCrashPassengersideRating',
#  'combinedSideBarrierAndPoleRating-Front',
#  'combinedSideBarrierAndPoleRating-Rear',
#  'sideBarrierRating-Overall',
#  'RolloverRating',
#  'RolloverRating2',
#  'RolloverPossibility',
#  'RolloverPossibility2',
#  'dynamicTipResult',
#  'SidePoleCrashRating',
#  'NHTSAElectronicStabilityControl',
#  'NHTSAForwardCollisionWarning',
#  'NHTSALaneDepartureWarning',
#  'ModelYear',
#  'Make',
#  'Model',
#  'VehicleDescription',
#  'VehicleId',
#  'rating_updated_on']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2469 entries, 0 to 2468
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   OverallRating                           2469 non-null   str
#  1   OverallFrontCrashRating                 2469 non-null   str
#  2   FrontCrashDriversideRating              2469 non-null   str
#  3   FrontCrashPassengersideRating           2469 non-null   str
#  4   OverallSideCrashRating                  2469 non-null   str
#  5   SideCrashDriversideRating               2469 non-null   str
#  6   SideCrashPassengersideRating            2469 non-null   str
#  7   combinedSideBarrierAndPoleRating-Front  2469 non-null   str
#  8   combinedSideBarrierAndPoleRating-Rear   2469 non-null   str
#  9   sideBarrierRating-Overall               2469 non-null   str
#  10  RolloverRating                          2469 non-null   str
# ...

# %%
df.isna().sum()
# Out:
# OverallRating                             0
# OverallFrontCrashRating                   0
# FrontCrashDriversideRating                0
# FrontCrashPassengersideRating             0
# OverallSideCrashRating                    0
# SideCrashDriversideRating                 0
# SideCrashPassengersideRating              0
# combinedSideBarrierAndPoleRating-Front    0
# combinedSideBarrierAndPoleRating-Rear     0
# sideBarrierRating-Overall                 0
# RolloverRating                            0
# RolloverRating2                           0
# RolloverPossibility                       0
# RolloverPossibility2                      0
# dynamicTipResult                          0
# SidePoleCrashRating                       0
# NHTSAElectronicStabilityControl           0
# NHTSAForwardCollisionWarning              0
# NHTSALaneDepartureWarning                 0
# ModelYear                                 0
# Make                                      0
# ...

# %%
df.nunique()
# Out:
# OverallRating                                5
# OverallFrontCrashRating                      5
# FrontCrashDriversideRating                   4
# FrontCrashPassengersideRating                5
# OverallSideCrashRating                       3
# SideCrashDriversideRating                    4
# SideCrashPassengersideRating                 4
# combinedSideBarrierAndPoleRating-Front       3
# combinedSideBarrierAndPoleRating-Rear        4
# sideBarrierRating-Overall                    3
# RolloverRating                               6
# RolloverRating2                              1
# RolloverPossibility                         76
# RolloverPossibility2                         1
# dynamicTipResult                             3
# SidePoleCrashRating                          5
# NHTSAElectronicStabilityControl              1
# NHTSAForwardCollisionWarning                 5
# NHTSALaneDepartureWarning                    6
# ModelYear                                    4
# ...
